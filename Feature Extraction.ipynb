# %%
# imports
import numpy as np
import pandas as pd

# %%
df = pd.read_json("clean_tweets.json")
print('dataframe length:', len(df))
df.columns
# Out:
# dataframe length: 6524
# Index(['username', 'description', 'date', 'location', 'following', 'followers',
#        'totaltweets', 'retweet', 'retweetcount', 'text', 'hashtags'],
#       dtype='object')

# %%
from nltk.tokenize import word_tokenize

def search_words(tweet, l):
    tokens = word_tokenize(tweet)
    res = []
    
    for w in l:
        if w in tokens:
            res.append(w)
            
    if len(res) == 0:
        return None
    return res

# %%
from nltk.stem import PorterStemmer
stemmer = PorterStemmer() 

brand = ['champagne', 'chardonnay', 'pinot', 'cabernet', 'noir', 'merlot', 'airen', 'sauvignon', 'tempranillo', 'syrah', 'garnacha', 'trebbiano']
color = ['red', 'white', 'rose', 'sparkling', 'redwine', 'whitewine', 'rosewine', 'sparklingwine']
country = ['italy', 'italian', 'spain', 'spanish', 'france', 'french', 'chile', 'chilean', 'australia', 'australian']

stem_brand = [stemmer.stem(w) for w in brand]
stem_color = [stemmer.stem(w) for w in color]
stem_country = [stemmer.stem(w) for w in country]

# %%
brand = []
color = []
country = []

for tweet in df['text']:
    brand.append(search_words(tweet, stem_brand))
    color.append(search_words(tweet, stem_color))
    country.append(search_words(tweet, stem_country))

df['brand'] = brand
df['color'] = color
df['country'] = country
    
df.head()
# Out:
#               username                                        description  \
# 0  1267886436080107521         Get your store up: https://t.co/qf78jAU5eo
# 1            406344750  The Best Tasting Wine Shop, a retail store wit...
# 2             83460300        Love wine... Love champagne... Love life...
# 3   853779552329502720  We tweet and retweet all things cool and inter...
# 4            838972202  Serial entrepreneur, that's taken two successf...
#
#                  date           location  following  followers  totaltweets  \
# 0 2022-10-03 18:06:57      United States         15         41         6223
# 1 2022-10-03 18:05:51    302 Pier Avenue       1939        995         2839
# 2 2022-10-03 18:05:48  Sydney, Australia       1107        589         3456
# 3 2022-10-03 18:05:07                           362        191        61865
# 4 2022-10-03 18:05:05   Delray Beach, FL       1029       8772        16697
#
#    retweet  retweetcount                                               text  \
# 0    False             0  repurposedupcycled green wine bottle base glas...
# 1    False             0  thanks much linda uncorked uncorkedwineshops w...
# 2    False             0  louis jadot charmes chambertin grand cru gtgtg...
# 3    False             7  deals events make feel larger life httpstcoscc...
# 4    False             0  become wine influencer six figures per year wi...
#
#                                             hashtags brand  color country
# 0  [Repurposedupcycled, Glasses, set, Bottle, win...  None   None    None
# 1  [Uncorked, UncorkedWineShops, wineshop, shoplo...  None   None    None
# 2             [AD, wine, redwine, whitewine, whisky]  None  [red]    None
# 3                           [soulnightevents, party]  None   None    None
# 4  [wine, winelovers, winetasting, wineisfun, fun...  None   None    None

# %%
df.to_json('tweets_with_features.json')

# %%
print('total number of rows:', len(df))
print(df['brand'].describe())
print()
print(df['color'].describe())
print()
print(df['country'].describe())
# Out:
# total number of rows: 6524
# count              548
# unique              31
# top       [chardonnay]
# freq               128
# Name: brand, dtype: object
#
# count       441
# unique        6
# top       [red]
# freq        247
# Name: color, dtype: object
#
# count           281
# unique           13
# top       [italian]
# freq             60
# Name: country, dtype: object

# %% [markdown]
# n-grams of:
# - grape
# - year
# - country
# - taste/winetaste

# %%
from nltk import ngrams
import collections

# Find all the n-grams in the given dictionary (grams)
# that contain the given word
# Returns a dictionary {(ngram): freq}
def find_words(word, grams):
    res = {}
    for ele in grams:
        if word in ele:
            res[ele] = grams[ele]
    return res

# returns a dictionary with {(ngram): freq}
def extract_ngrams(tweet):
    tokens = word_tokenize(tweet)
    ngram = ngrams(tokens, 2)
    freq = collections.Counter(ngram)
    ngram = ngrams(tokens, 3)
    freq += collections.Counter(ngram)
    
    return freq

ngram_freq = {} # dictionary with {(ngram): freq}

for tweet in df['text']: # extract ngrams for all tweets
    ngrams_found = extract_ngrams(tweet)
    
    for gram in ngrams_found:
        if gram in ngram_freq:
            ngram_freq[gram] += ngrams_found[gram]
        else:
            ngram_freq[gram] = ngrams_found[gram]
            
sorted_ngram_freq = sorted(ngram_freq.items(), key=lambda item: item[1], reverse = True)

# %%
# Find all the ngrams that contains the given word
# and prints them in descending frequency order
word = 'grape'
elements = find_words(word, ngram_freq)
sorted_elements = sorted(elements.items(), key=lambda item: item[1], reverse = True)
sorted_elements
# Out:
# [(('wine', 'grape'), 8),
#  (('grape', 'varieties'), 7),
#  (('grape', 'harvest'), 6),
#  (('refers', 'grape'), 5),
#  (('grape', 'region'), 5),
#  (('term', 'refers', 'grape'), 5),
#  (('refers', 'grape', 'region'), 5),
#  (('grape', 'wine'), 4),
#  (('grape', 'guide'), 4),
#  (('wine', 'grape', 'guide'), 4),
#  (('grape', 'skin'), 3),
#  (('red', 'wine', 'grape'), 3),
#  (('grape', 'juice'), 3),
#  (('grape', 'vines'), 2),
#  (('grape', 'growers'), 2),
#  (('grape', 'skins'), 2),
#  (('grape', 'say'), 2),
#  (('guess', 'grape'), 2),
#  (('white', 'grape'), 2),
#  (('grape', 'variety'), 2),
#  (('grape', 'variety', 'wine'), 2),
#  (('grape', 'varietals'), 2),
#  (('grape', 'amp'), 2),
#  (('grape', 'amp', 'wine'), 2),
#  (('grape', 'growing'), 2),
#  (('greece', 'grape'), 2),
#  (('grape', 'pink'), 2),
#  (('peloponnese', 'greece', 'grape'), 2),
#  (('greece', 'grape', 'pink'), 2),
#  (('grape', 'pink', 'skins'), 2),
#  (('separates', 'grape'), 1),
#  (('production', 'separates', 'grape'), 1),
#  (('separates', 'grape', 'skin'), 1),
#  (('grape', 'skin', 'mean'), 1),
#  (('monica', 'grape'), 1),
#  (('island', 'monica', 'grape'), 1),
#  (('monica', 'grape', 'vines'), 1),
#  (('grape', 'vines', 'grown'), 1),
#  (('grape', 'growers', 'researching'), 1),
#  (('beloved', 'grape'), 1),
#  (('preserve', 'beloved', 'grape'), 1),
#  (('beloved', 'grape', 'varieties'), 1),
#  (('grape', 'varieties', 'capricious'), 1),
#  (('aka', 'grape'), 1),
#  (('grape', 'waste'), 1),
#  (('pomace', 'aka', 'grape'), 1),
#  (('aka', 'grape', 'waste'), 1),
#  (('grape', 'waste', 'year'), 1),
#  (('chablis', 'grape'), 1),
#  (('chablis', 'grape', 'harvest'), 1),
#  (('grape', 'harvest', 'chablis'), 1),
#  (('traditional', 'grape'), 1),
#  (('wineharvest', 'traditional', 'grape'), 1),
#  (('traditional', 'grape', 'wine'), 1),
#  (('grape', 'wine', 'festival'), 1),
#  (('mingling', 'grape'), 1),
#  (('varietals', 'mingling', 'grape'), 1),
#  (('mingling', 'grape', 'skins'), 1),
#  (('grape', 'skins', 'juice'), 1),
#  (('season', 'grape'), 1),
#  (('grape', 'corporate'), 1),
#  (('tis', 'season', 'grape'), 1),
#  (('season', 'grape', 'corporate'), 1),
#  (('grape', 'corporate', 'events'), 1),
#  (('grape', 'different'), 1),
#  (('grape', 'different', 'characteristics'), 1),
#  (('demeter', 'grape'), 1),
#  (('grape', 'winetasting'), 1),
#  (('biodynamic', 'demeter', 'grape'), 1),
#  (('demeter', 'grape', 'winetasting'), 1),
#  (('grape', 'winetasting', 'photo'), 1),
#  (('grapes', 'grape'), 1),
#  (('grape', 'grapes'), 1),
#  (('days', 'grapes', 'grape'), 1),
#  (('grapes', 'grape', 'grapes'), 1),
#  (('grape', 'grapes', 'wine'), 1),
#  (('grape', 'say', 'crushed'), 1),
#  (('–', 'grape'), 1),
#  (('france', '–', 'grape'), 1),
#  (('–', 'grape', 'skins'), 1),
#  (('grape', 'skins', 'private'), 1),
#  (('identify', 'grape'), 1),
#  (('learning', 'identify', 'grape'), 1),
#  (('identify', 'grape', 'varieties'), 1),
#  (('grape', 'varieties', 'winescience'), 1),
#  (('one', 'grape'), 1),
#  (('say', 'grape'), 1),
#  (('grape', 'going'), 1),
#  (('one', 'grape', 'say'), 1),
#  (('grape', 'say', 'grape'), 1),
#  (('say', 'grape', 'going'), 1),
#  (('grape', 'going', 'get'), 1),
#  (('complete', 'wine', 'grape'), 1),
#  (('grape', 'guide', 'httpstcowmxdiryg'), 1),
#  (('grape', 'guide', 'httpstcoxrbxenj'), 1),
#  (('grape', 'guide', 'httpstcozewqlao'), 1),
#  (('grape', 'guide', 'httpstcozewqm'), 1),
#  (('different', 'grape'), 1),
#  (('three', 'different', 'grape'), 1),
#  (('different', 'grape', 'varieties'), 1),
#  (('grape', 'varieties', '–'), 1),
#  (('grape', 'answer'), 1),
#  (('guess', 'grape', 'answer'), 1),
#  (('grape', 'answer', 'httpstcomcjsxiyb'), 1),
#  (('features', 'grape'), 1),
#  (('grape', 'used'), 1),
#  (('nationale', 'features', 'grape'), 1),
#  (('features', 'grape', 'used'), 1),
#  (('grape', 'used', 'port'), 1),
#  (('festival', 'grape'), 1),
#  (('grape', 'underway'), 1),
#  (('festival', 'grape', 'underway'), 1),
#  (('grape', 'underway', 'festivalofthegrape'), 1),
#  (('wineregion', 'grape'), 1),
#  (('grape', 'appellation'), 1),
#  (('winelabel', 'wineregion', 'grape'), 1),
#  (('wineregion', 'grape', 'appellation'), 1),
#  (('grape', 'appellation', 'sparklingwine'), 1),
#  (('grape', 'vinegar'), 1),
#  (('white', 'wine', 'grape'), 1),
#  (('wine', 'grape', 'vinegar'), 1),
#  (('grape', 'vinegar', 'made'), 1),
#  (('least', 'grape'), 1),
#  (('regions', 'least', 'grape'), 1),
#  (('least', 'grape', 'varieties'), 1),
#  (('grape', 'varieties', 'choice'), 1),
#  (('perfumed', 'white', 'grape'), 1),
#  (('white', 'grape', 'variety'), 1),
#  (('finished', 'grape'), 1),
#  (('finished', 'grape', 'harvest'), 1),
#  (('grape', 'harvest', 'vabrik'), 1),
#  (('k', 'grape'), 1),
#  (('grape', 'vineyard'), 1),
#  (('k', 'grape', 'vineyard'), 1),
#  (('grape', 'vineyard', 'httpstcouxkoqrhap'), 1),
#  (('juice', 'grape'), 1),
#  (('grapefruit', 'juice', 'grape'), 1),
#  (('juice', 'grape', 'juice'), 1),
#  (('grape', 'juice', 'michelada'), 1),
#  (('new', 'grape'), 1),
#  (('use', 'new', 'grape'), 1),
#  (('new', 'grape', 'varietals'), 1),
#  (('grape', 'varietals', 'start'), 1),
#  (('grape', 'region', 'httpstconhygpuf'), 1),
#  (('grape', 'region', 'httpstcowxdre'), 1),
#  (('grape', 'region', 'httpstcoqykxhftyz'), 1),
#  (('grape', 'glass'), 1),
#  (('grape', 'glass', 'wine'), 1),
#  (('bottling', 'grape'), 1),
#  (('homemade', 'bottling', 'grape'), 1),
#  (('bottling', 'grape', 'wine'), 1),
#  (('grape', 'wine', 'one'), 1),
#  (('nelsoncryptoman', 'grape'), 1),
#  (('nelsoncryptoman', 'grape', 'amp'), 1),
#  (('tintore', 'grape'), 1),
#  (('grape', 'prephilloxera'), 1),
#  (('dark', 'grape'), 1),
#  (('grape', 'gets'), 1),
#  (('tintore', 'grape', 'prephilloxera'), 1),
#  (('grape', 'prephilloxera', 'valley'), 1),
#  (('tramonti', 'dark', 'grape'), 1),
#  (('dark', 'grape', 'gets'), 1),
#  (('grape', 'gets', 'harvested'), 1),
#  (('grape', 'region', 'httpstcotlyidy'), 1),
#  (('mint', 'grape'), 1),
#  (('free', 'mint', 'grape'), 1),
#  (('mint', 'grape', 'vines'), 1),
#  (('grape', 'vines', 'paid'), 1),
#  (('italian', 'grape'), 1),
#  (('grape', 'indigenous'), 1),
#  (('leftover', 'grape'), 1),
#  (('sagrantino', 'italian', 'grape'), 1),
#  (('italian', 'grape', 'indigenous'), 1),
#  (('grape', 'indigenous', 'umbria'), 1),
#  (('w', 'leftover', 'grape'), 1),
#  (('leftover', 'grape', 'skin'), 1),
#  (('grape', 'skin', 'anise'), 1),
#  (('grenache', 'grape'), 1),
#  (('grape', 'httpstcodcxpkpqa'), 1),
#  (('wines', 'grenache', 'grape'), 1),
#  (('grenache', 'grape', 'httpstcodcxpkpqa'), 1),
#  (('grape', 'httpstcodcxpkpqa', 'hope'), 1),
#  (('australian', 'grape'), 1),
#  (('korea', 'australian', 'grape'), 1),
#  (('australian', 'grape', 'amp'), 1),
#  (('something', 'grape'), 1),
#  (('grape', 'weekend'), 1),
#  (('something', 'grape', 'weekend'), 1),
#  (('grape', 'weekend', 'today'), 1),
#  (('grape', 'often'), 1),
#  (('”', 'white', 'grape'), 1),
#  (('white', 'grape', 'often'), 1),
#  (('grape', 'often', 'associated'), 1),
#  (('update', 'grape'), 1),
#  (('update', 'grape', 'harvest'), 1),
#  (('grape', 'harvest', 'finger'), 1),
#  (('orange', 'grape'), 1),
#  (('viticulture', 'grape'), 1),
#  (('canberra', 'orange', 'grape'), 1),
#  (('orange', 'grape', 'growing'), 1),
#  (('grape', 'growing', 'regions'), 1),
#  (('agriculture', 'viticulture', 'grape'), 1),
#  (('viticulture', 'grape', 'wine'), 1),
#  (('grape', 'wine', 'httpstcosjeehissj'), 1),
#  (('grape', 'region', 'httpstcoontasvmg'), 1),
#  (('grape', 'pinotgris'), 1),
#  (('winelovers', 'wine', 'grape'), 1),
#  (('wine', 'grape', 'pinotgris'), 1),
#  (('bountiful', 'grape'), 1),
#  (('washingtons', 'bountiful', 'grape'), 1),
#  (('bountiful', 'grape', 'harvest'), 1),
#  (('grape', 'harvest', 'seattle'), 1),
#  (('california', 'wine', 'grape'), 1),
#  (('wine', 'grape', 'growers'), 1),
#  (('grape', 'growers', 'north'), 1),
#  (('contains', 'grape'), 1),
#  (('wine', 'contains', 'grape'), 1),
#  (('contains', 'grape', 'skin'), 1),
#  (('grape', 'skin', 'color'), 1),
#  (('posip', 'grape'), 1),
#  (('grape', 'make'), 1),
#  (('try', 'posip', 'grape'), 1),
#  (('posip', 'grape', 'make'), 1),
#  (('grape', 'make', 'mergavicta'), 1),
#  (('zinfandel', 'grape'), 1),
#  (('grape', 'also'), 1),
#  (('show', 'zinfandel', 'grape'), 1),
#  (('zinfandel', 'grape', 'also'), 1),
#  (('grape', 'also', 'known'), 1),
#  (('grape', 'harvest', 'bins'), 1),
#  (('grape', 'httpstcoiejhdako'), 1),
#  (('varietal', 'guess', 'grape'), 1),
#  (('guess', 'grape', 'httpstcoiejhdako'), 1),
#  (('grape', 'httpstcoiejhdako', 'harvest'), 1),
#  (('year', 'grape'), 1),
#  (('time', 'year', 'grape'), 1),
#  (('year', 'grape', 'harvest'), 1),
#  (('grape', 'harvest', 'across'), 1),
#  (('winelovers', 'grape'), 1),
#  (('httpstcoxekypfvp', 'winelovers', 'grape'), 1),
#  (('winelovers', 'grape', 'varietals'), 1),
#  (('grape', 'varietals', 'northernitaly'), 1),
#  (('recognised', 'grape'), 1),
#  (('even', 'recognised', 'grape'), 1),
#  (('recognised', 'grape', 'varieties'), 1),
#  (('grape', 'varieties', 'travels'), 1),
#  (('ready', 'grape'), 1),
#  (('grape', 'stomping'), 1),
#  (('get', 'ready', 'grape'), 1),
#  (('ready', 'grape', 'stomping'), 1),
#  (('grape', 'stomping', 'httpstcoaecxdzf'), 1),
#  (('prosecco', 'grape'), 1),
#  (('grape', 'explodes'), 1),
#  (('glera', 'prosecco', 'grape'), 1),
#  (('prosecco', 'grape', 'explodes'), 1),
#  (('grape', 'explodes', 'varietal'), 1),
#  (('science', 'grape'), 1),
#  (('viticulture', 'science', 'grape'), 1),
#  (('science', 'grape', 'growing'), 1),
#  (('grape', 'growing', 'cultivation'), 1),
#  (('seeds', 'wine', 'grape'), 1),
#  (('wine', 'grape', 'varieties'), 1),
#  (('grape', 'varieties', 'used'), 1),
#  (('favorite', 'grape'), 1),
#  (('grape', 'unique'), 1),
#  (('styles', 'favorite', 'grape'), 1),
#  (('favorite', 'grape', 'unique'), 1),
#  (('grape', 'unique', 'educational'), 1),
#  (('letting', 'grape'), 1),
#  (('technique', 'letting', 'grape'), 1),
#  (('letting', 'grape', 'juice'), 1),
#  (('grape', 'juice', 'macerate'), 1),
#  (('katsunuma', 'grape'), 1),
#  (('day', 'katsunuma', 'grape'), 1),
#  (('katsunuma', 'grape', 'wine'), 1),
#  (('grape', 'wine', 'amp'), 1),
#  (('complicated', 'grape'), 1),
#  (('pleasures', 'complicated', 'grape'), 1),
#  (('complicated', 'grape', 'varieties'), 1),
#  (('grape', 'varieties', 'styles'), 1),
#  (('illinoisgrown', 'grape'), 1),
#  (('guess', 'illinoisgrown', 'grape'), 1),
#  (('illinoisgrown', 'grape', 'variety'), 1),
#  (('cellarsa', 'grape'), 1),
#  (('grape', '’'), 1),
#  (('chase', 'cellarsa', 'grape'), 1),
#  (('cellarsa', 'grape', '’'), 1),
#  (('grape', '’', 'journey'), 1),
#  (('going', 'grape'), 1),
#  (('grape', 'pie'), 1),
#  (('gems', 'going', 'grape'), 1),
#  (('going', 'grape', 'pie'), 1),
#  (('grape', 'pie', 'weekend'), 1),
#  (('fermented', 'grape'), 1),
#  (('distilled', 'fermented', 'grape'), 1),
#  (('fermented', 'grape', 'juice'), 1),
#  (('grape', 'juice', 'perhaps'), 1),
#  (('interested', 'grape'), 1),
#  (('grape', 'picking'), 1),
#  (('youre', 'interested', 'grape'), 1),
#  (('interested', 'grape', 'picking'), 1),
#  (('grape', 'picking', 'hours'), 1)]
