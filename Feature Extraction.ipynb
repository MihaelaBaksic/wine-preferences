# %%
# imports
import numpy as np
import pandas as pd

# %%
df = pd.read_json("clean_tweets.json")
print('dataframe length:', len(df))
df.columns
# Out:
# dataframe length: 6524
# Index(['username', 'description', 'date', 'location', 'following', 'followers',
#        'totaltweets', 'retweet', 'retweetcount', 'text', 'hashtags'],
#       dtype='object')

# %%
from nltk.tokenize import word_tokenize

def search_words(tweet, l):
    tokens = word_tokenize(tweet)
    res = []
    
    for w in l:
        if w in tokens:
            res.append(w)
            
    if len(res) == 0:
        return None
    return res

# %%
from nltk.stem import PorterStemmer
stemmer = PorterStemmer() 

brand = ['champagne', 'chardonnay', 'pinot', 'cabernet', 'noir', 'merlot', 'airen', 'sauvignon', 'tempranillo', 'syrah', 'garnacha', 'trebbiano']
color = ['red', 'white', 'rose', 'sparkling', 'redwine', 'whitewine', 'rosewine', 'sparklingwine']
country = ['italy', 'italian', 'spain', 'spanish', 'france', 'french', 'chile', 'chilean', 'australia', 'australian']

stem_brand = [stemmer.stem(w) for w in brand]
stem_color = [stemmer.stem(w) for w in color]
stem_country = [stemmer.stem(w) for w in country]

# %%
brand = []
color = []
country = []

for tweet in df['text']:
    brand.append(search_words(tweet, stem_brand))
    color.append(search_words(tweet, stem_color))
    country.append(search_words(tweet, stem_country))

df['brand'] = brand
df['color'] = color
df['country'] = country
    
df.head()
# Out:
#               username                                        description  \
# 0  1267886436080107521         Get your store up: https://t.co/qf78jAU5eo
# 1            406344750  The Best Tasting Wine Shop, a retail store wit...
# 2             83460300        Love wine... Love champagne... Love life...
# 3   853779552329502720  We tweet and retweet all things cool and inter...
# 4            838972202  Serial entrepreneur, that's taken two successf...
#
#                  date           location  following  followers  totaltweets  \
# 0 2022-10-03 18:06:57      United States         15         41         6223
# 1 2022-10-03 18:05:51    302 Pier Avenue       1939        995         2839
# 2 2022-10-03 18:05:48  Sydney, Australia       1107        589         3456
# 3 2022-10-03 18:05:07                           362        191        61865
# 4 2022-10-03 18:05:05   Delray Beach, FL       1029       8772        16697
#
#    retweet  retweetcount                                               text  \
# 0    False             0  repurposedupcycled green wine bottle base glas...
# 1    False             0  thanks much linda uncorked uncorkedwineshops w...
# 2    False             0  louis jadot charmes chambertin grand cru gtgtg...
# 3    False             7  deals events make feel larger life httpstcoscc...
# 4    False             0  become wine influencer six figures per year wi...
#
#                                             hashtags brand  color country
# 0  [Repurposedupcycled, Glasses, set, Bottle, win...  None   None    None
# 1  [Uncorked, UncorkedWineShops, wineshop, shoplo...  None   None    None
# 2             [AD, wine, redwine, whitewine, whisky]  None  [red]    None
# 3                           [soulnightevents, party]  None   None    None
# 4  [wine, winelovers, winetasting, wineisfun, fun...  None   None    None

# %%
df.to_json('tweets_with_features.json')

# %%
print('total number of rows:', len(df))
print(df['brand'].describe())
print()
print(df['color'].describe())
print()
print(df['country'].describe())
# Out:
# total number of rows: 6524
# count              548
# unique              31
# top       [chardonnay]
# freq               128
# Name: brand, dtype: object
#
# count       441
# unique        6
# top       [red]
# freq        247
# Name: color, dtype: object
#
# count           281
# unique           13
# top       [italian]
# freq             60
# Name: country, dtype: object

# %% [markdown]
# n-grams of:
# - grape
# - year
# - country
# - taste/winetaste

# %%
from nltk import ngrams
import collections

# Find all the n-grams in the given dictionary (grams)
# that contain the given word
# Returns a dictionary {(ngram): freq}
def find_words(word, grams):
    res = {}
    for ele in grams:
        if word in ele:
            res[ele] = grams[ele]
    return res

# returns a dictionary with {(ngram): freq}
def extract_ngrams(tweet):
    tokens = word_tokenize(tweet)
    ngram = ngrams(tokens, 2)
    freq = collections.Counter(ngram)
    ngram = ngrams(tokens, 3)
    freq += collections.Counter(ngram)
    
    return freq

ngram_freq = {} # dictionary with {(ngram): freq}

for tweet in df['text']: # extract ngrams for all tweets
    ngrams_found = extract_ngrams(tweet)
    
    for gram in ngrams_found:
        if gram in ngram_freq:
            ngram_freq[gram] += ngrams_found[gram]
        else:
            ngram_freq[gram] = ngrams_found[gram]
            
sorted_ngram_freq = sorted(ngram_freq.items(), key=lambda item: item[1], reverse = True)

# %%
# Find all the ngrams that contains the given word
# and prints them in descending frequency order
word = 'taste'
elements = find_words(word, ngram_freq)
sorted_elements = sorted(elements.items(), key=lambda item: item[1], reverse = True)
sorted_elements
# Out:
# [(('taste', 'like'), 6),
#  (('taste', 'wine'), 6),
#  (('come', 'taste'), 5),
#  (('taste', 'like', 'sommelier'), 5),
#  (('taste', 'wines'), 5),
#  (('amp', 'taste'), 3),
#  (('want', 'taste'), 3),
#  (('taste', 'buds'), 3),
#  (('vineyards', 'taste'), 3),
#  (('wine', 'taste'), 3),
#  (('taste', 'award'), 2),
#  (('taste', 'award', 'winning'), 2),
#  (('taste', 'champagne'), 2),
#  (('taste', 'champagne', 'wine'), 2),
#  (('taste', 'winespectators'), 2),
#  (('wine', 'want', 'taste'), 2),
#  (('want', 'taste', 'winespectators'), 2),
#  (('taste', 'winespectators', 'new'), 2),
#  (('taste', 'enjoy'), 2),
#  (('specialtycoffee', 'taste'), 2),
#  (('taste', 'experience'), 2),
#  (('specialtycoffee', 'taste', 'experience'), 2),
#  (('taste', 'experience', 'dcfoodie'), 2),
#  (('taste', 'test'), 2),
#  (('taste', 'amazing'), 2),
#  (('taste', 'cédric'), 2),
#  (('tour', 'vineyards', 'taste'), 2),
#  (('vineyards', 'taste', 'cédric'), 2),
#  (('taste', 'cédric', 'bourez'), 2),
#  (('great', 'taste'), 2),
#  (('october', 'taste'), 2),
#  (('taste', 'good'), 2),
#  (('taste', 'wine', 'like'), 2),
#  (('rumba', 'taste'), 2),
#  (('taste', 'tropics'), 2),
#  (('bortoli', 'rumba', 'taste'), 2),
#  (('rumba', 'taste', 'tropics'), 2),
#  (('taste', 'tropics', 'liqueur'), 2),
#  (('smells', 'amp', 'taste'), 1),
#  (('amp', 'taste', 'like'), 1),
#  (('taste', 'like', 'wine'), 1),
#  (('growths', 'taste'), 1),
#  (('taste', 'mouton'), 1),
#  (('first', 'growths', 'taste'), 1),
#  (('growths', 'taste', 'mouton'), 1),
#  (('taste', 'mouton', 'margaux'), 1),
#  (('festival', 'taste'), 1),
#  (('taste', 'bardolino'), 1),
#  (('wine', 'festival', 'taste'), 1),
#  (('festival', 'taste', 'bardolino'), 1),
#  (('taste', 'bardolino', 'chiaretto'), 1),
#  (('sweet', 'taste'), 1),
#  (('taste', 'brew'), 1),
#  (('amp', 'sweet', 'taste'), 1),
#  (('sweet', 'taste', 'brew'), 1),
#  (('taste', 'brew', 'wine'), 1),
#  (('cellar', 'taste'), 1),
#  (('visit', 'cellar', 'taste'), 1),
#  (('cellar', 'taste', 'award'), 1),
#  (('chance', 'taste'), 1),
#  (('heres', 'chance', 'taste'), 1),
#  (('chance', 'taste', 'award'), 1),
#  (('one', 'taste'), 1),
#  (('taste', 'httpstcojzxdnfidcy'), 1),
#  (('like', 'one', 'taste'), 1),
#  (('one', 'taste', 'httpstcojzxdnfidcy'), 1),
#  (('taste', 'httpstcojzxdnfidcy', 'bourbonbarrel'), 1),
#  (('dry', 'taste'), 1),
#  (('taste', 'subtle'), 1),
#  (('flavors', 'dry', 'taste'), 1),
#  (('dry', 'taste', 'subtle'), 1),
#  (('taste', 'subtle', 'saltiness'), 1),
#  (('tastebetter', 'taste'), 1),
#  (('taste', 'instawine'), 1),
#  (('betterlife', 'tastebetter', 'taste'), 1),
#  (('tastebetter', 'taste', 'instawine'), 1),
#  (('taste', 'instawine', 'instashop'), 1),
#  (('complements', 'taste'), 1),
#  (('sourness', 'complements', 'taste'), 1),
#  (('complements', 'taste', 'wine'), 1),
#  (('taste', 'wine', 'vino'), 1),
#  (('taste', 'call'), 1),
#  (('wine', 'come', 'taste'), 1),
#  (('come', 'taste', 'call'), 1),
#  (('taste', 'call', 'make'), 1),
#  (('vintage', 'taste'), 1),
#  (('taste', 'mosaictop'), 1),
#  (('new', 'vintage', 'taste'), 1),
#  (('vintage', 'taste', 'mosaictop'), 1),
#  (('taste', 'mosaictop', 'wosauk'), 1),
#  (('floral', 'taste'), 1),
#  (('taste', 'complex'), 1),
#  (('lovely', 'floral', 'taste'), 1),
#  (('floral', 'taste', 'complex'), 1),
#  (('taste', 'complex', 'fruits'), 1),
#  (('rhine', 'taste'), 1),
#  (('taste', 'alsace'), 1),
#  (('wine', 'rhine', 'taste'), 1),
#  (('rhine', 'taste', 'alsace'), 1),
#  (('taste', 'alsace', 'france'), 1),
#  (('taste', 'different'), 1),
#  (('submission', 'amp', 'taste'), 1),
#  (('amp', 'taste', 'different'), 1),
#  (('taste', 'different', 'organicsustainable'), 1),
#  (('dont', 'taste'), 1),
#  (('wines', 'dont', 'taste'), 1),
#  (('dont', 'taste', 'wines'), 1),
#  (('taste', 'wines', 'foodwriter'), 1),
#  (('excellent', 'taste'), 1),
#  (('taste', 'exquisite'), 1),
#  (('wine', 'excellent', 'taste'), 1),
#  (('excellent', 'taste', 'exquisite'), 1),
#  (('taste', 'exquisite', 'finesse'), 1),
#  (('today', 'taste'), 1),
#  (('decisions…decisions', 'today', 'taste'), 1),
#  (('today', 'taste', 'champagne'), 1),
#  (('even', 'taste'), 1),
#  (('taste', 'httpstcoangdevzv'), 1),
#  (('smell', 'even', 'taste'), 1),
#  (('even', 'taste', 'httpstcoangdevzv'), 1),
#  (('taste', 'httpstcoangdevzv', 'kitchen'), 1),
#  (('invites', 'taste'), 1),
#  (('taste', 'multiple'), 1),
#  (('restaurant', 'invites', 'taste'), 1),
#  (('invites', 'taste', 'multiple'), 1),
#  (('taste', 'multiple', 'dishes'), 1),
#  (('alluring', 'taste'), 1),
#  (('taste', 'wild'), 1),
#  (('sahyadri', 'taste'), 1),
#  (('taste', 'grandeur'), 1),
#  (('dense', 'alluring', 'taste'), 1),
#  (('alluring', 'taste', 'wild'), 1),
#  (('taste', 'wild', 'organic'), 1),
#  (('heart', 'sahyadri', 'taste'), 1),
#  (('sahyadri', 'taste', 'grandeur'), 1),
#  (('taste', 'grandeur', 'resvera'), 1),
#  (('delivered', 'taste'), 1),
#  (('flavor', 'delivered', 'taste'), 1),
#  (('delivered', 'taste', 'buds'), 1),
#  (('taste', 'buds', 'whenever'), 1),
#  (('plenty', 'taste'), 1),
#  (('pm', 'plenty', 'taste'), 1),
#  (('plenty', 'taste', 'enjoy'), 1),
#  (('taste', 'enjoy', 'look'), 1),
#  (('amwritingfiction', 'taste'), 1),
#  (('taste', 'httpstcoiadxzldzt'), 1),
#  (('writingcommunity', 'amwritingfiction', 'taste'), 1),
#  (('amwritingfiction', 'taste', 'httpstcoiadxzldzt'), 1),
#  (('see', 'taste'), 1),
#  (('taste', 'dm'), 1),
#  (('wait', 'see', 'taste'), 1),
#  (('see', 'taste', 'dm'), 1),
#  (('taste', 'dm', 'want'), 1),
#  (('cant', 'taste'), 1),
#  (('taste', 'flowers'), 1),
#  (('wine', 'cant', 'taste'), 1),
#  (('cant', 'taste', 'flowers'), 1),
#  (('taste', 'flowers', 'cant'), 1),
#  (('sgws', 'taste'), 1),
#  (('taste', 'best'), 1),
#  (('sgws', 'taste', 'best'), 1),
#  (('taste', 'best', 'full'), 1),
#  (('food', 'taste'), 1),
#  (('taste', 'grocery'), 1),
#  (('samples', 'food', 'taste'), 1),
#  (('food', 'taste', 'grocery'), 1),
#  (('taste', 'grocery', 'foodie'), 1),
#  (('backtolife', 'specialtycoffee', 'taste'), 1),
#  (('fish', 'taste'), 1),
#  (('taste', 'right'), 1),
#  (('fish', 'taste', 'right'), 1),
#  (('taste', 'right', 'must'), 1),
#  (('men', 'taste'), 1),
#  (('taste', 'httpstcozxlqwjlk'), 1),
#  (('cellars', 'men', 'taste'), 1),
#  (('men', 'taste', 'httpstcozxlqwjlk'), 1),
#  (('taste', 'history'), 1),
#  (('vineyard', 'come', 'taste'), 1),
#  (('come', 'taste', 'history'), 1),
#  (('taste', 'history', 'specializing'), 1),
#  (('wineart', 'taste'), 1),
#  (('taste', 'freedom'), 1),
#  (('wineart', 'taste', 'freedom'), 1),
#  (('taste', 'freedom', 'apollo'), 1),
#  (('podcast', 'taste'), 1),
#  (('taste', 'syrah'), 1),
#  (('latest', 'podcast', 'taste'), 1),
#  (('podcast', 'taste', 'syrah'), 1),
#  (('taste', 'syrah', 'discuss'), 1),
#  (('old', 'taste'), 1),
#  (('taste', 'year'), 1),
#  (('’', 'old', 'taste'), 1),
#  (('old', 'taste', 'year'), 1),
#  (('taste', 'year', 'feel'), 1),
#  (('things', 'taste'), 1),
#  (('taste', 'today'), 1),
#  (('things', 'taste', 'today'), 1),
#  (('taste', 'today', 'live'), 1),
#  (('taste', 'france'), 1),
#  (('taste', 'france', 'famille'), 1),
#  (('bitter', 'taste'), 1),
#  (('soften', 'bitter', 'taste'), 1),
#  (('bitter', 'taste', 'wine'), 1),
#  (('ones', 'taste'), 1),
#  (('vs', 'ones', 'taste'), 1),
#  (('ones', 'taste', 'test'), 1),
#  (('taste', 'test', 'know'), 1),
#  (('today', 'amp', 'taste'), 1),
#  (('amp', 'taste', 'amazing'), 1),
#  (('taste', 'amazing', 'wines'), 1),
#  (('free', 'taste'), 1),
#  (('taste', '’'), 1),
#  (('us', 'free', 'taste'), 1),
#  (('free', 'taste', '’'), 1),
#  (('taste', '’', 'simple'), 1),
#  (('taste', 'age'), 1),
#  (('tradition', 'taste'), 1),
#  (('taste', 'valleys'), 1),
#  (('website', 'taste'), 1),
#  (('taste', 'caves'), 1),
#  (('aged', 'wine', 'taste'), 1),
#  (('wine', 'taste', 'age'), 1),
#  (('taste', 'age', 'old'), 1),
#  (('centuries', 'tradition', 'taste'), 1),
#  (('tradition', 'taste', 'valleys'), 1),
#  (('taste', 'valleys', 'piedmont'), 1),
#  (('visit', 'website', 'taste'), 1),
#  (('website', 'taste', 'caves'), 1),
#  (('taste', 'caves', 'piedmont'), 1),
#  (('get', 'taste'), 1),
#  (('taste', 'california'), 1),
#  (('get', 'taste', 'california'), 1),
#  (('taste', 'california', 'wine'), 1),
#  (('taste', 'officialbelaire'), 1),
#  (('come', 'taste', 'officialbelaire'), 1),
#  (('taste', 'officialbelaire', 'today'), 1),
#  (('gladly', 'taste'), 1),
#  (('wed', 'gladly', 'taste'), 1),
#  (('gladly', 'taste', 'test'), 1),
#  (('taste', 'test', 'every'), 1),
#  (('weekend', 'taste'), 1),
#  (('taste', 'pleasure'), 1),
#  (('pleasure', 'weekend', 'taste'), 1),
#  (('weekend', 'taste', 'pleasure'), 1),
#  (('taste', 'pleasure', 'rest'), 1),
#  (('happier', 'taste'), 1),
#  (('taste', 'rich'), 1),
#  (('couldnt', 'happier', 'taste'), 1),
#  (('happier', 'taste', 'rich'), 1),
#  (('taste', 'rich', 'aroma'), 1),
#  (('saliva', 'taste'), 1),
#  (('taste', 'balance'), 1),
#  (('structure', 'saliva', 'taste'), 1),
#  (('saliva', 'taste', 'balance'), 1),
#  (('taste', 'balance', 'tart'), 1),
#  (('house', 'taste'), 1),
#  (('centuryold', 'house', 'taste'), 1),
#  (('house', 'taste', 'wines'), 1),
#  (('taste', 'wines', 'douro'), 1),
#  (('interested', 'taste'), 1),
#  (('special', 'taste'), 1),
#  (('lover', 'interested', 'taste'), 1),
#  (('interested', 'taste', 'enjoy'), 1),
#  (('taste', 'enjoy', 'special'), 1),
#  (('enjoy', 'special', 'taste'), 1),
#  (('special', 'taste', 'champagne'), 1),
#  (('taste', 'wine', 'sommeliers'), 1),
#  (('saturday', 'taste'), 1),
#  (('taste', 'due'), 1),
#  (('dallas', 'saturday', 'taste'), 1),
#  (('saturday', 'taste', 'due'), 1),
#  (('taste', 'due', 'santi'), 1),
#  (('taste', 'killer'), 1),
#  (('places', 'taste'), 1),
#  (('distant', 'vineyards', 'taste'), 1),
#  (('vineyards', 'taste', 'killer'), 1),
#  (('taste', 'killer', 'offerings'), 1),
#  (('top', 'places', 'taste'), 1),
#  (('places', 'taste', 'wine'), 1),
#  (('taste', 'wine', 'state'), 1),
#  (('travel', 'taste'), 1),
#  (('taste', 'wanderlust'), 1),
#  (('explore', 'travel', 'taste'), 1),
#  (('travel', 'taste', 'wanderlust'), 1),
#  (('taste', 'wanderlust', 'thursdaymorning'), 1),
#  (('taste', 'finest'), 1),
#  (('taste', 'finest', 'jfw'), 1),
#  (('taste', 'packs'), 1),
#  (('’', 'great', 'taste'), 1),
#  (('great', 'taste', 'packs'), 1),
#  (('taste', 'packs', 'tropical'), 1),
#  (('taste', 'wining'), 1),
#  (('httpstcoyqxnxta', 'wine', 'taste'), 1),
#  (('wine', 'taste', 'wining'), 1),
#  (('taste', 'wining', 'music'), 1),
#  (('refined', 'taste'), 1),
#  (('taste', 'loved'), 1),
#  (('evolution', 'refined', 'taste'), 1),
#  (('refined', 'taste', 'loved'), 1),
#  (('taste', 'loved', 'celebrated'), 1),
#  (('come', 'taste', 'amazing'), 1),
#  (('taste', 'amazing', 'products'), 1),
#  (('festival', 'october', 'taste'), 1),
#  (('october', 'taste', 'buds'), 1),
#  (('taste', 'buds', 'thank'), 1),
#  (('pm', 'taste'), 1),
#  (('want', 'taste', 'wines'), 1),
#  (('taste', 'wines', 'beautiful'), 1),
#  (('saturday', 'pm', 'taste'), 1),
#  (('pm', 'taste', 'wines'), 1),
#  (('taste', 'wines', 'veneto'), 1),
#  (('tasting', 'taste'), 1),
#  (('taste', 'radio'), 1),
#  (('music', 'tasting', 'taste'), 1),
#  (('tasting', 'taste', 'radio'), 1),
#  (('taste', 'radio', 'wednesday'), 1),
#  (('grapes', 'taste'), 1),
#  (('sauce', 'grapes', 'taste'), 1),
#  (('taste', 'good', 'sounds'), 1),
#  (('tickle', 'taste'), 1),
#  (('blends', 'tickle', 'taste'), 1),
#  (('tickle', 'taste', 'buds'), 1),
#  (('taste', 'buds', 'wine'), 1),
#  (('advise', 'taste'), 1),
#  (('taste', 'suggestions'), 1),
#  (('pairings', 'advise', 'taste'), 1),
#  (('advise', 'taste', 'suggestions'), 1),
#  (('httpstcockexprln', 'taste'), 1),
#  (('taste', 'palate'), 1),
#  (('winespectator', 'httpstcockexprln', 'taste'), 1),
#  (('httpstcockexprln', 'taste', 'palate'), 1),
#  (('taste', 'palate', 'winelovers'), 1),
#  (('available', 'taste'), 1),
#  (('taste', 'free'), 1),
#  (('price', 'available', 'taste'), 1),
#  (('available', 'taste', 'free'), 1),
#  (('taste', 'free', 'week'), 1),
#  (('weekday', 'specialtycoffee', 'taste'), 1),
#  (('taste', 'great'), 1),
#  (('clean', 'wine', 'taste'), 1),
#  (('wine', 'taste', 'great'), 1),
#  (('taste', 'great', 'drink'), 1),
#  (('subtle', 'taste'), 1),
#  (('taste', 'honeysuckle'), 1),
#  (('pickup', 'subtle', 'taste'), 1),
#  (('subtle', 'taste', 'honeysuckle'), 1),
#  (('taste', 'honeysuckle', 'nuttiness'), 1),
#  (('best', 'taste'), 1),
#  (('taste', 'older'), 1),
#  (('use', 'best', 'taste'), 1),
#  (('best', 'taste', 'older'), 1),
#  (('taste', 'older', 'vintage'), 1),
#  (('premier', 'great', 'taste'), 1),
#  (('great', 'taste', 'good'), 1),
#  (('taste', 'good', 'bad'), 1),
#  (('learn', 'taste'), 1),
#  (('taste', 'amp'), 1),
#  (('regions', 'learn', 'taste'), 1),
#  (('learn', 'taste', 'amp'), 1),
#  (('taste', 'amp', 'enjoy'), 1),
#  (('sale', 'come', 'taste'), 1),
#  (('come', 'taste', 'wines'), 1),
#  (('taste', 'wines', 'topwineries'), 1),
#  (('taste', 'discover'), 1),
#  (('th', 'october', 'taste'), 1),
#  (('october', 'taste', 'discover'), 1),
#  (('taste', 'discover', 'wines'), 1),
#  (('characterized', 'taste'), 1),
#  (('taste', 'guava'), 1),
#  (('rosé', 'characterized', 'taste'), 1),
#  (('characterized', 'taste', 'guava'), 1),
#  (('taste', 'guava', 'cherry'), 1),
#  (('cider', 'taste'), 1),
#  (('taste', 'httpstcoiyiqiqd'), 1),
#  (('soju', 'cider', 'taste'), 1),
#  (('cider', 'taste', 'httpstcoiyiqiqd'), 1),
#  (('welwyn', 'taste'), 1),
#  (('taste', 'majestic'), 1),
#  (('counter', 'welwyn', 'taste'), 1),
#  (('welwyn', 'taste', 'majestic'), 1),
#  (('taste', 'majestic', 'wine'), 1),
#  (('support', 'taste'), 1),
#  (('taste', 'exclusive'), 1),
#  (('savor', 'support', 'taste'), 1),
#  (('support', 'taste', 'exclusive'), 1),
#  (('taste', 'exclusive', 'wines'), 1),
#  (('’', 'taste'), 1),
#  (('’', 'taste', 'wine'), 1),
#  (('supertuscan', 'taste'), 1),
#  (('taste', 'httpstcooumtqx'), 1),
#  (('redwine', 'supertuscan', 'taste'), 1),
#  (('supertuscan', 'taste', 'httpstcooumtqx'), 1),
#  (('tomorrow', 'taste'), 1),
#  (('taste', 'flight'), 1),
#  (('stop', 'tomorrow', 'taste'), 1),
#  (('tomorrow', 'taste', 'flight'), 1),
#  (('taste', 'flight', 'italian'), 1),
#  (('elegant', 'taste'), 1),
#  (('taste', 'balanced'), 1),
#  (('chocolate', 'elegant', 'taste'), 1),
#  (('elegant', 'taste', 'balanced'), 1),
#  (('taste', 'balanced', 'wellstructured'), 1)]

# %%
import nltk
import spacy
 
# essential entity models downloads
nltk.downloader.download('maxent_ne_chunker')
nltk.downloader.download('words')
nltk.downloader.download('treebank')
nltk.downloader.download('maxent_treebank_pos_tagger')
nltk.downloader.download('punkt')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     /home/aina/nltk_data...
# [nltk_data]   Unzipping chunkers/maxent_ne_chunker.zip.
# [nltk_data] Downloading package words to /home/aina/nltk_data...
# [nltk_data]   Unzipping corpora/words.zip.
# [nltk_data] Downloading package treebank to /home/aina/nltk_data...
# [nltk_data]   Unzipping corpora/treebank.zip.
# [nltk_data] Downloading package maxent_treebank_pos_tagger to
# [nltk_data]     /home/aina/nltk_data...
# [nltk_data]   Unzipping taggers/maxent_treebank_pos_tagger.zip.
# [nltk_data] Downloading package punkt to /home/aina/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/aina/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# True

# %%
# !python -m spacy download en_core_web_sm
# Out:
# 2022-10-07 13:55:05.215668: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-10-07 13:55:05.215704: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2022-10-07 13:55:07.084893: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2022-10-07 13:55:07.084925: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-10-07 13:55:07.084949: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (aina-X555LJ): /proc/driver/nvidia/version does not exist
# Collecting en-core-web-sm==3.4.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.4.0/en_core_web_sm-3.4.0-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 811.0 kB/s eta 0:00:00m eta 0:00:010:00:01
# Requirement already satisfied: spacy<3.5.0,>=3.4.0 in /home/aina/tmp/PATH/lib/python3.7/site-packages (from en-core-web-sm==3.4.0) (3.4.1)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in /home/aina/tmp/PATH/lib/python3.7/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (0.4.2)
# Requirement already satisfied: pathy>=0.3.5 in /home/aina/tmp/PATH/lib/python3.7/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (0.6.2)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in /home/aina/tmp/PATH/lib/python3.7/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (0.10.1)
# Requirement already satisfied: jinja2 in /home/aina/tmp/PATH/lib/python3.7/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (2.10.1)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /home/aina/tmp/PATH/lib/python3.7/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (1.0.3)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /home/aina/tmp/PATH/lib/python3.7/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (3.3.0)
# Requirement already satisfied: packaging>=20.0 in /home/aina/tmp/PATH/lib/python3.7/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (21.3)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /home/aina/tmp/PATH/lib/python3.7/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (1.0.8)
# Requirement already satisfied: numpy>=1.15.0 in /home/aina/tmp/PATH/lib/python3.7/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (1.21.6)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /home/aina/tmp/PATH/lib/python3.7/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (2.0.8)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in /home/aina/tmp/PATH/lib/python3.7/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (8.1.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.10.0,>=1.7.4 in /home/aina/tmp/PATH/lib/python3.7/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (1.9.2)
# Requirement already satisfied: setuptools in /home/aina/tmp/PATH/lib/python3.7/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (41.0.1)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /home/aina/tmp/PATH/lib/python3.7/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (3.0.7)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /home/aina/tmp/PATH/lib/python3.7/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (2.0.6)
# Requirement already satisfied: typing-extensions<4.2.0,>=3.7.4 in /home/aina/tmp/PATH/lib/python3.7/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (4.1.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /home/aina/tmp/PATH/lib/python3.7/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (2.4.4)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /home/aina/tmp/PATH/lib/python3.7/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (4.64.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.9 in /home/aina/tmp/PATH/lib/python3.7/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (3.0.10)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /home/aina/tmp/PATH/lib/python3.7/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (2.23.0)
# Requirement already satisfied: zipp>=0.5 in /home/aina/tmp/PATH/lib/python3.7/site-packages (from catalogue<2.1.0,>=2.0.6->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (0.5.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/aina/tmp/PATH/lib/python3.7/site-packages (from packaging>=20.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (2.4.0)
# Requirement already satisfied: smart-open<6.0.0,>=5.2.1 in /home/aina/tmp/PATH/lib/python3.7/site-packages (from pathy>=0.3.5->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (5.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /home/aina/tmp/PATH/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (2019.6.16)
# Requirement already satisfied: idna<3,>=2.5 in /home/aina/tmp/PATH/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (2.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /home/aina/tmp/PATH/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /home/aina/tmp/PATH/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (1.25.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /home/aina/tmp/PATH/lib/python3.7/site-packages (from thinc<8.2.0,>=8.1.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (0.0.2)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /home/aina/tmp/PATH/lib/python3.7/site-packages (from thinc<8.2.0,>=8.1.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (0.7.8)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /home/aina/tmp/PATH/lib/python3.7/site-packages (from typer<0.5.0,>=0.3.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (8.1.3)
# Requirement already satisfied: MarkupSafe>=0.23 in /home/aina/tmp/PATH/lib/python3.7/site-packages (from jinja2->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (1.1.1)
# Requirement already satisfied: importlib-metadata in /home/aina/tmp/PATH/lib/python3.7/site-packages (from click<9.0.0,>=7.1.1->typer<0.5.0,>=0.3.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (4.11.3)
# Installing collected packages: en-core-web-sm
# Successfully installed en-core-web-sm-3.4.0
# WARNING: You are using pip version 22.0.3; however, version 22.2.2 is available.
# You should consider upgrading via the '/home/aina/tmp/PATH/bin/python -m pip install --upgrade pip' command.
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
import locationtagger
 
# initializing sample text
sample_text = "India has very rich and vivid culture widely\
        spread from Kerala to Nagaland to Haryana to Maharashtra. " \
       "Mumbai being financial capital can be said better\
       than some western cities such as " \
       " Lahore, Canberra etc. Pakistan and Nepal share its borders"
 
# extracting entities.
place_entity = locationtagger.find_locations(text = sample_text)
 
# getting all country regions
print("The countries regions in text : ")
print(place_entity.country_regions)
 
# getting all country cities
print("The countries cities in text : ")
print(place_entity.country_cities)
 
# getting all other countries
print("All other countries in text : ")
print(place_entity.other_countries)
 
# getting all region cities
print("The region cities in text : ")
print(place_entity.region_cities)
 
# getting all other regions
print("All other regions in text : ")
print(place_entity.other_regions)
 
# getting all other entities
print("All other entities in text : ")
print(place_entity.other)
# Out:
# The countries regions in text :
# {'India': ['Maharashtra', 'Haryana', 'Kerala', 'Nagaland']}
# The countries cities in text :
# {'India': ['Mumbai', 'Haryana'], 'Australia': ['Canberra'], 'Pakistan': ['Lahore']}
# All other countries in text :
# ['India', 'Australia', 'Pakistan']
# The region cities in text :
# {'Maharashtra': ['Mumbai'], 'Australian Capital Territory': ['Canberra'], 'Punjab': ['Lahore'], 'Haryana': ['Haryana']}
# All other regions in text :
# ['Maharashtra', 'Australian Capital Territory', 'Punjab', 'Haryana']
# All other entities in text :
# []

# %%
# Extract country and city from each location

location_country = []
location_city = []

for location in df['location']:
    if location != '':
        try:
            place_entity = locationtagger.find_locations(text = location)
            location_country.append(place_entity.countries)
            location_city.append(place_entity.cities)
        except:
            print(location)
            location_country.append(None)
            location_city.append(None)
    else:
        location_country.append(None)
        location_city.append(None)
                
df['location_country'] = location_country
df['location_city'] = location_city
# Out:
# Harare, Zimbabwe

# %%
# Extract city from location

location_city = []

for location in df['location']:
    if location != '':
        try:
            place_entity = locationtagger.find_locations(text = location)
            location_city.append(place_entity.cities)
        except:
            print(location)
            location_city.append(None)
    else:
        location_city.append(None)
                
df['location_city'] = location_city
# Out:
# Harare, Zimbabwe

# %%
df.head()
# Out:
#               username                                        description  \
# 0  1267886436080107521         Get your store up: https://t.co/qf78jAU5eo
# 1            406344750  The Best Tasting Wine Shop, a retail store wit...
# 2             83460300        Love wine... Love champagne... Love life...
# 3   853779552329502720  We tweet and retweet all things cool and inter...
# 4            838972202  Serial entrepreneur, that's taken two successf...
#
#                  date           location  following  followers  totaltweets  \
# 0 2022-10-03 18:06:57      United States         15         41         6223
# 1 2022-10-03 18:05:51    302 Pier Avenue       1939        995         2839
# 2 2022-10-03 18:05:48  Sydney, Australia       1107        589         3456
# 3 2022-10-03 18:05:07                           362        191        61865
# 4 2022-10-03 18:05:05   Delray Beach, FL       1029       8772        16697
#
#    retweet  retweetcount                                               text  \
# 0    False             0  repurposedupcycled green wine bottle base glas...
# 1    False             0  thanks much linda uncorked uncorkedwineshops w...
# 2    False             0  louis jadot charmes chambertin grand cru gtgtg...
# 3    False             7  deals events make feel larger life httpstcoscc...
# 4    False             0  become wine influencer six figures per year wi...
#
#                                             hashtags brand  color country  \
# 0  [Repurposedupcycled, Glasses, set, Bottle, win...  None   None    None
# 1  [Uncorked, UncorkedWineShops, wineshop, shoplo...  None   None    None
# 2             [AD, wine, redwine, whitewine, whisky]  None  [red]    None
# 3                           [soulnightevents, party]  None   None    None
# 4  [wine, winelovers, winetasting, wineisfun, fun...  None   None    None
#
#   location_country          location_city
# 0  [United States]                     []
# 1               []               [Avenue]
# 2      [Australia]               [Sydney]
# 3             None                   None
# 4               []  [Delray Beach, Beach]
